# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

import warnings 
warnings.filterwarnings("ignore") 
warnings.warn("this will not show")

# %matplotlib inline

plt.rcParams["figure.figsize"] = (10,6)

sns.set_style("whitegrid") 
pd.set_option('display.float_format', lambda x: '%.3f' % x)

pd.options.display.max_rows = 150 
pd.options.display.max_columns = 100

# %%
print(sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'exercise', 'flights', 'fmri', 'gammas', 'geyser', 'iris', 'mpg', 'penguins', 'planets', 'taxis', 'tips', 'titanic']

# %%
tips = sns.load_dataset("tips")

# %%
tips.shape
# Out:
# (244, 7)

# %%
tips.describe().T
# Out:
#              count   mean   std   min    25%    50%    75%    max
# total_bill 244.000 19.786 8.902 3.070 13.348 17.795 24.127 50.810
# tip        244.000  2.998 1.384 1.000  2.000  2.900  3.562 10.000
# size       244.000  2.570 0.951 1.000  2.000  2.000  3.000  6.000

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0      16.990 1.010  Female     No  Sun  Dinner     2
# 1      10.340 1.660    Male     No  Sun  Dinner     3
# 2      21.010 3.500    Male     No  Sun  Dinner     3
# 3      23.680 3.310    Male     No  Sun  Dinner     2
# 4      24.590 3.610  Female     No  Sun  Dinner     4

# %%
tips.day.value_counts().plot.bar();

# %%
sns.countplot(x="day", data=tips); #figure and axes

# %%
fig, ax = plt.subplots();

# %%
ax = sns.countplot(x="day", data=tips)

# %%
#p.get_height()

# %%
fig, ax = plt.subplots()
ax = sns.countplot(x="day", data=tips)
for p in ax.patches:
    # getter and setter (methods to retrieve and set values)
    #properties (decorators or call them)
    ax.annotate((p.get_height()), (p.get_x() +.4, p.get_height()+1))
        # ax.annotate(<what>, <x> <y>)
fig.show()

# %%
fig, ax = plt.subplots()
ax = sns.countplot(x="day", data=tips)
for p in ax.patches:
    # getter and setter (methods to retrieve and set values)
    #properties (decorators or call them)
    ax.annotate((p.get_height()), (p.get_x() +.4, p.get_height()+1))
        # ax.annotate(<what>, <x> <y>)
ax.annotate("momm", (p.get_x() +.3, p.get_height()+1.5))
fig.show()

# %%
ax.patches
# Out:
# [<matplotlib.patches.Rectangle at 0x2299f313490>,
#  <matplotlib.patches.Rectangle at 0x2299f313b20>,
#  <matplotlib.patches.Rectangle at 0x229a0a80fd0>,
#  <matplotlib.patches.Rectangle at 0x229a0a804c0>]

# %%
dir(ax.patch)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_agg_filter',
#  '_alias_map',
#  '_alpha',
#  '_animated',
#  '_antialiased',
#  '_axes',
#  '_bind_draw_path_function',
#  '_capstyle',
#  '_clipon',
#  '_clippath',
#  '_contains',
#  '_convert_units',
#  '_convert_xy_units',
#  '_dashes',
#  '_dashoffset',
#  '_default_contains',
#  '_edge_default',
#  '_edgecolor',
#  '_facecolor',
#  '_fill',
#  '_get_clipping_extent_bbox',
#  '_gid',
#  '_hatch',
#  '_hatch_color',
#  '_height',
#  '_in_layout',
#  '_joinstyle',
#  '_label',
#  '_linestyle',
#  '_linewidth',
#  '_mouseover',
#  '_oid',
#  '_original_edgecolor',
#  '_original_facecolor',
#  '_path_effects',
#  '_picker',
#  '_process_radius',
#  '_propobservers',
#  '_rasterized',
#  '_rect_transform',
#  '_remove_method',
#  '_set_edgecolor',
#  '_set_facecolor',
#  '_set_gc_clip',
#  '_sketch',
#  '_snap',
#  '_stale',
#  '_sticky_edges',
#  '_transform',
#  '_transformSet',
#  '_update_patch_transform',
#  '_update_x1',
#  '_update_y1',
#  '_url',
#  '_us_dashes',
#  '_visible',
#  '_width',
#  '_x0',
#  '_x1',
#  '_y0',
#  '_y1',
#  'add_callback',
#  'angle',
#  'axes',
#  'clipbox',
#  'contains',
#  'contains_point',
#  'contains_points',
#  'convert_xunits',
#  'convert_yunits',
#  'draw',
#  'eventson',
#  'figure',
#  'fill',
#  'findobj',
#  'format_cursor_data',
#  'get_aa',
#  'get_agg_filter',
#  'get_alpha',
#  'get_animated',
#  'get_antialiased',
#  'get_bbox',
#  'get_capstyle',
#  'get_children',
#  'get_clip_box',
#  'get_clip_on',
#  'get_clip_path',
#  'get_contains',
#  'get_cursor_data',
#  'get_data_transform',
#  'get_ec',
#  'get_edgecolor',
#  'get_extents',
#  'get_facecolor',
#  'get_fc',
#  'get_figure',
#  'get_fill',
#  'get_gid',
#  'get_hatch',
#  'get_height',
#  'get_in_layout',
#  'get_joinstyle',
#  'get_label',
#  'get_linestyle',
#  'get_linewidth',
#  'get_ls',
#  'get_lw',
#  'get_patch_transform',
#  'get_path',
#  'get_path_effects',
#  'get_picker',
#  'get_rasterized',
#  'get_sketch_params',
#  'get_snap',
#  'get_tightbbox',
#  'get_transform',
#  'get_transformed_clip_path_and_affine',
#  'get_url',
#  'get_verts',
#  'get_visible',
#  'get_width',
#  'get_window_extent',
#  'get_x',
#  'get_xy',
#  'get_y',
#  'get_zorder',
#  'have_units',
#  'is_transform_set',
#  'mouseover',
#  'pchanged',
#  'pick',
#  'pickable',
#  'properties',
#  'remove',
#  'remove_callback',
#  'set',
#  'set_aa',
#  'set_agg_filter',
#  'set_alpha',
#  'set_animated',
#  'set_antialiased',
#  'set_bounds',
#  'set_capstyle',
#  'set_clip_box',
#  'set_clip_on',
#  'set_clip_path',
#  'set_color',
#  'set_contains',
#  'set_ec',
#  'set_edgecolor',
#  'set_facecolor',
#  'set_fc',
#  'set_figure',
#  'set_fill',
#  'set_gid',
#  'set_hatch',
#  'set_height',
#  'set_in_layout',
#  'set_joinstyle',
#  'set_label',
#  'set_linestyle',
#  'set_linewidth',
#  'set_ls',
#  'set_lw',
#  'set_path_effects',
#  'set_picker',
#  'set_rasterized',
#  'set_sketch_params',
#  'set_snap',
#  'set_transform',
#  'set_url',
#  'set_visible',
#  'set_width',
#  'set_x',
#  'set_xy',
#  'set_y',
#  'set_zorder',
#  'stale',
#  'stale_callback',
#  'sticky_edges',
#  'update',
#  'update_from',
#  'validCap',
#  'validJoin',
#  'xy',
#  'zorder']

# %%
sns.countplot(x="day" , data=tips, hue="sex");

ax1 = sns.countplot(x="day", data=tips)
for p in ax1.patches:
    # getter and setter (methods to retrieve and set values)
    #properties (decorators or call them)
    ax.annotate((p.get_height()), (p.get_x() +.4, p.get_height()+1))
        # ax.annotate(<what>, <x> <y>)

# %%
fig, ax = plt.subplots()
ax = sns.countplot(x="day", data=tips, hue="sex", ax=ax)

for p in ax.patches:
    ax.annotate(p.get_height(), (p.get_x()+0.1, p.get_height()+1))

# %%
sns.barplot(x="total_bill", y="sex", data=tips);

# %%
sns.barplot(y="total_bill", x="sex", data=tips);

# %%
sns.barplot(x="total_bill", y="sex", data=tips, ci="sd");

# %%
print(sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'exercise', 'flights', 'fmri', 'gammas', 'geyser', 'iris', 'mpg', 'penguins', 'planets', 'taxis', 'tips', 'titanic']

# %%
tips = sns.load_dataset("tips")

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0      16.990 1.010  Female     No  Sun  Dinner     2
# 1      10.340 1.660    Male     No  Sun  Dinner     3
# 2      21.010 3.500    Male     No  Sun  Dinner     3
# 3      23.680 3.310    Male     No  Sun  Dinner     2
# 4      24.590 3.610  Female     No  Sun  Dinner     4

# %%
tips.shape
# Out:
# (244, 7)

# %%
tips.describe().T
# Out:
#              count   mean   std   min    25%    50%    75%    max
# total_bill 244.000 19.786 8.902 3.070 13.348 17.795 24.127 50.810
# tip        244.000  2.998 1.384 1.000  2.000  2.900  3.562 10.000
# size       244.000  2.570 0.951 1.000  2.000  2.000  3.000  6.000

# %%
tips.describe(include="all")
# Out:
#         total_bill     tip   sex smoker  day    time    size
# count      244.000 244.000   244    244  244     244 244.000
# unique         NaN     NaN     2      2    4       2     NaN
# top            NaN     NaN  Male     No  Sat  Dinner     NaN
# freq           NaN     NaN   157    151   87     176     NaN
# mean        19.786   2.998   NaN    NaN  NaN     NaN   2.570
# std          8.902   1.384   NaN    NaN  NaN     NaN   0.951
# min          3.070   1.000   NaN    NaN  NaN     NaN   1.000
# 25%         13.348   2.000   NaN    NaN  NaN     NaN   2.000
# 50%         17.795   2.900   NaN    NaN  NaN     NaN   2.000
# 75%         24.127   3.562   NaN    NaN  NaN     NaN   3.000
# max         50.810  10.000   NaN    NaN  NaN     NaN   6.000

# %%
tips["day"].value_counts()
# Out:
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: day, dtype: int64

# %%
sns.countplot(x="day", data=tips);

# %%
fig, ax = plt.subplots()

ax = sns.countplot(x="day", data=tips)

for p in ax.patches:
    ax.annotate(p.get_height(), (p.get_x()+0.4, p.get_height()+1))

    
plt.show()

# %%
fig, ax = plt.subplots()

ax = sns.countplot(x="time", data=tips)

for p in ax.patches:
    ax.annotate(p.get_height(), (p.get_x()+0.3, p.get_height()+1))

    
plt.show()

# %%
sns.countplot(x="time", data=tips, hue="smoker");

# %%
ax = sns.countplot(x="day", hue="time", data=tips)

for p in ax.patches:
    ax.annotate(p.get_height(), (p.get_x()+0.1, p.get_height()+1))

# %%
fig, ax = plt.subplots()
ax = sns.countplot(x='day', data=tips, hue="sex")
for p in ax.patches:
    ax.annotate((p.get_height()), (p.get_x()+0.1, p.get_height()+1))
    ax.text(p.get_x()+0.05, p.get_height()-4, str(round(p.get_height()/tips.day.count(), 2))) # yüzdelik ekledik

# %%
mpg = sns.load_dataset("mpg")
mpg.head()
# Out:
#      mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0 18.000          8       307.000     130.000    3504        12.000
# 1 15.000          8       350.000     165.000    3693        11.500
# 2 18.000          8       318.000     150.000    3436        11.000
# 3 16.000          8       304.000     150.000    3433        12.000
# 4 17.000          8       302.000     140.000    3449        10.500
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
sns.countplot(x="cylinders", data=mpg);

# %%
sns.countplot(x="model_year", data=mpg);

# %%
sns.countplot(x="origin", data=mpg);

# %%
sns.countplot(x="model_year", hue="origin", data=mpg);

# %%
# countplot gets catogorical value on x axis and outputs counts on y axis

# %%
# barplot returns an estimation between two values. also returns confidence interval(default is 95)

# %%
sns.barplot(x="sex", y="total_bill", data=tips);

# %%
sns.barplot(x="sex", y="total_bill", ci="sd", data=tips);

# %%
sns.barplot(x="sex", y="total_bill", ci="sd", data=tips, hue="smoker"); # ci = confidence interval

# %%
sns.barplot(x="day", y="total_bill", data=tips);

# %%
sns.barplot(x="sex", y="total_bill", data=tips, estimator=np.sum);

# %%
sns.barplot(x="day", y="total_bill", data=tips, estimator=np.sum);

# %%
sns.barplot(x="day", y="total_bill", data=tips);

# %%
fig, ax = plt.subplots(1,2)

sns.barplot(x="day", y="total_bill", data=tips, ax=ax[0])

sns.countplot(x="day", data=tips, ax=ax[1])

plt.tight_layout()

# %%
sns.boxplot(x="day", y="total_bill", data=tips);

# %%
sns.boxplot(x="day", y="total_bill", data=tips, hue="sex");

plt.legend(bbox_to_anchor=(1.05,1), loc=2, borderaxespad=0.2);

# %%
sns.boxplot(x="day", y="total_bill", data=tips, hue="sex");

plt.legend(bbox_to_anchor=(1.05,1), loc=2, borderaxespad=0.1);

# %%
plt.figure(figsize=(14,8))
sns.boxplot(x="day", y="total_bill", data=tips, hue="sex");

# %%
plt.figure(figsize=(14,5))
sns.boxplot(x="total_bill", y="day", data=tips, hue="sex", orient="h");
plt.show()

# %%
plt.figure(figsize=(14,5))
sns.boxplot(x="total_bill", y="day", data=tips, hue="sex");
plt.show()

# %%
plt.figure(figsize=(14,5))
sns.boxplot(x="total_bill", y="day", data=tips, hue="sex", width=0.8);
plt.show();
plt.tight_layout();

# %%
plt.figure(figsize=(14,5))
sns.boxplot(x="day", y="total_bill", data=tips, hue="sex", width=0.8);
plt.show()

# %%
plt.figure(figsize=(14,5))
sns.boxplot(x="day", y="total_bill", data=tips, hue="sex", width=0.5);
plt.show()

# %%
df = pd.read_csv("StudentsPerformance.csv")
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
plt.figure(figsize=(14,8))
sns.boxplot(x="parental level of education", y="math score", data=df)
plt.show()

# %%
plt.figure(figsize=(14,8))
sns.boxplot(x="parental level of education", y="math score", data=df)
plt.xticks(rotation=45);

# %%
plt.figure(figsize=(16,10))
sns.boxplot(x="parental level of education", y="math score", data=df, hue="gender")
plt.legend(bbox_to_anchor=(1.05,1), loc=2, borderaxespad=0.1 )
plt.show()

# %%
plt.figure(figsize=(16,10))
sns.boxplot(x="parental level of education", y="math score", data=df, hue="gender")
plt.show()

# %%
sns.violinplot(x="day", y="total_bill", data=tips)
plt.show()

# %%
sns.violinplot(x="day", y="total_bill", data=tips, hue="sex")
plt.show()

# %%
plt.figure(figsize=(14,10))
sns.violinplot(y="day", x="total_bill", data=tips, hue="sex")
plt.show()

# %%
sns.violinplot(x="parental level of education", y="math score", data=df, hue="gender")
plt.show()

# %%
sns.violinplot(x="parental level of education", y="math score", data=df, hue="gender", split=True)
plt.show()

# %%
plt.figure(figsize=(14,8))
sns.violinplot(x="parental level of education", y="math score", data=df, hue="gender", inner=None)
plt.show()

# %%
plt.figure(figsize=(14,8))
sns.violinplot(x="parental level of education", y="math score", data=df, hue="gender", inner="quartile")
plt.show()

# %%
plt.figure(figsize=(14,8))
sns.violinplot(x="parental level of education", y="math score", data=df, hue="gender", split=True, inner="quartile")
plt.show()

# %%
plt.figure(figsize=(14,8))
sns.violinplot(x="parental level of education", y="math score", data=df, bw=0.2)
plt.show()

# %%
plt.figure(figsize=(14,8))
sns.violinplot(x="parental level of education", y="math score", data=df, bw=0.1)
plt.show()

# %%
plt.figure(figsize=(14,8))
sns.violinplot(y="parental level of education", x="math score", data=df, bw=0.1)
plt.show()
