# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")
warnings.warn("this will not show")

# %matplotlib inline

plt.rcParams["figure.figsize"] = (10,6)

sns.set_style("whitegrid")
pd.set_option('display.float_format', lambda x: '%.3f' % x)

pd.options.display.max_rows = 150
pd.options.display.max_columns = 100

# %%
cars = sns.load_dataset("mpg")
cars.head()
# Out:
#      mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0 18.000          8       307.000     130.000    3504        12.000
# 1 15.000          8       350.000     165.000    3693        11.500
# 2 18.000          8       318.000     150.000    3436        11.000
# 3 16.000          8       304.000     150.000    3433        12.000
# 4 17.000          8       302.000     140.000    3449        10.500
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
sns.displot(x="weight", data=cars)

# %%
sns.displot(x="weight", data=cars, kde=True)

# %%
sns.displot(x="weight", data=cars, kind="kde")

# %%
sns.displot(x="weight", data=cars, kind="ecdf")

# %%
sns.displot(x="weight", data=cars, kind="kde", rug=True)

# %%
sns.displot(x="weight", data=cars, hue="origin")

# %%
sns.displot(x="weight", data=cars,kind="kde", hue="origin")

# %%
sns.displot(x="weight", y="horsepower", data=cars)

# %%
sns.displot(x="weight", y="horsepower", data=cars, kind="kde")

# %%
sns.displot(x="weight", y="horsepower", data=cars, kind="kde", rug=True)

# %%
sns.displot(x="weight", data=cars, hue="origin")

# %%
sns.displot(x="weight", data=cars, hue="origin", col="origin");

# %%
sns.displot(x="weight", data=cars, col="origin", kind="kde");

# %%
sns.displot(x="weight", data=cars, col="origin", kind="kde", rug=True);

# %%
sns.displot(x="weight", data=cars[cars.cylinders.isin([4,6,8])], 
                                  col="origin",row="cylinders",
                                  hue="cylinders");

# %%
sns.displot(x="weight", data=cars,
            hue="origin", col="origin",
           palette="crest");

# %%
sns.displot(x="weight", data=cars,
            hue="origin", col="origin");

# %%
sns.displot(x="weight", data=cars
            , col="origin",
           palette="crest");

# %%
sns.displot(x="weight", data=cars,
            col="origin",
           height=2);

# %%
sns.displot(x="weight", data=cars,
            col="origin",
           height=2, aspect=1.5);

# %%
sns.displot(x="weight", data=cars,
            bins=20);

# %%
sns.displot(x="weight", data=cars,
            kind="kde",fill=True);

# %%
sns.displot(x="weight", data=cars,
            kind="kde",fill=True,
           lw=3);

# %%
sns.displot(x="weight", data=cars,
            kind="kde",fill=True, lw=3,
            rug=True,
           rug_kws=({"height":0.05}));

# %%
sns.displot(x="weight", data=cars,
            col="origin", 
           facet_kws={"despine":False});

# %%
g = sns.displot(x="weight", data=cars,
               col="origin");

# %%
type(g)
# Out:
# seaborn.axisgrid.FacetGrid

# %%
g.axes_dict.items()
# Out:
# dict_items([('usa', <AxesSubplot:title={'center':'origin = usa'}, xlabel='weight', ylabel='Count'>), ('japan', <AxesSubplot:title={'center':'origin = japan'}, xlabel='weight'>), ('europe', <AxesSubplot:title={'center':'origin = europe'}, xlabel='weight'>)])

# %%
g = sns.displot(x="weight", data=cars,
               col="origin");
for col_val, ax in g.axes_dict.items():
    if col_val=="europe":
        ax.set_facecolor("E2F2FF")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-43-e040d49b2abc> in <module>
#       3 for col_val, ax in g.axes_dict.items():
#       4     if col_val=="europe":
# ----> 5         ax.set_facecolor("E2F2FF")
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_base.py in set_facecolor(self, color)
#    1191         self._facecolor = color
#    1192         self.stale = True
# -> 1193         return self.patch.set_facecolor(color)
#    1194
#    1195     def _set_title_offset_trans(self, title_offset_points):
#
# ~\anaconda3\lib\site-packages\matplotlib\patches.py in set_facecolor(self, color)
#     353         """
#     354         self._original_facecolor = color
# --> 355         self._set_facecolor(color)
#     356
#     357     def set_color(self, c):
#
# ~\anaconda3\lib\site-packages\matplotlib\patches.py in _set_facecolor(self, color)
#     341             color = mpl.rcParams['patch.facecolor']
#     342         alpha = self._alpha if self._fill else 0
# --> 343         self._facecolor = colors.to_rgba(color, alpha)
#     344         self.stale = True
#     345
#
# ~\anaconda3\lib\site-packages\matplotlib\colors.py in to_rgba(c, alpha)
#     187         rgba = None
#     188     if rgba is None:  # Suppress exception chaining of cache lookup failure.
# --> 189         rgba = _to_rgba_no_colorcycle(c, alpha)
#     190         try:
#     191             _colors_full_map.cache[c, alpha] = rgba
#
# ~\anaconda3\lib\site-packages\matplotlib\colors.py in _to_rgba_no_colorcycle(c, alpha)
#     258                     f"Value must be within 0-1 range")
#     259             return c, c, c, alpha if alpha is not None else 1.
# --> 260         raise ValueError(f"Invalid RGBA argument: {orig_c!r}")
#     261     # tuple color.
#     262     if not np.iterable(c):
#
# ValueError: Invalid RGBA argument: 'E2F2FF'
